# %%
import os
import tarfile

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from six.moves import urllib

# %%
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
filtered_housing =  housing.loc[:, housing.columns!='ocean_proximity'] # pronaci kako radi sa sa DROP

# %%
filtered_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
corr_housing = filtered_housing.corr()

# %%
corr_housing
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
sns.heatmap(corr_housing.corr());

# %% [markdown]
# Korelacija ide od $[-1, 1]$.
#
# 1234
# 4321
#
#
#
# 1234
# 2468

# %%
dict = {
    "Age": [20, 24, 22, 22, 22],
    "Gender": ["single", "single", "single", "single", "single"]
}

df = pd.DataFrame.from_dict(dict)

# %%
df.head()
# Out:
#    Age  Gender
# 0   20  single
# 1   24  single
# 2   22  single
# 3   22  single
# 4   22  single

# %% [markdown]
# # Istraziti parquet fajlove

# %% [markdown]
# # PySpark

# %% [markdown]
# $1,2,3,   4,5,6,   7,8,9$ terba nam metoda max
#
# $3  6  9$
#
# $9$

# %%
onlinefood = pd.read_csv("onlinefoods.csv")

# %%
onlinefood.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
onlinefood['Age'].head()
# Out:
# 0    20
# 1    24
# 2    22
# 3    22
# 4    22
# Name: Age, dtype: int64

# %%
100 je New york (150K)
71000 je Sarajevo (15K)
100 000 San Fracisco (175K)

# %%
onlinefood.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
onlinefood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
onlinefood.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
onlinefood_filtered = onlinefood[ (onlinefood['Age'] < 30) & (onlinefood['Family size'] == 2) ]

# %%
onlinefood_filtered.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  101.000000        101.0  101.000000  101.000000     101.000000
# mean    23.841584          2.0   12.966446   77.599434  560041.811881
# std      2.239342          0.0    0.041119    0.050115      31.871214
# min     19.000000          2.0   12.883400   77.484200  560001.000000
# 25%     22.000000          2.0   12.934300   77.563700  560015.000000
# 50%     24.000000          2.0   12.975700   77.592100  560034.000000
# 75%     26.000000          2.0   12.992500   77.622100  560070.000000
# max     28.000000          2.0   13.073400   77.758200  560103.000000

# %%
onlinefood_filtered.head()
# Out:
#     Age  Gender Marital Status Occupation   Monthly Income  \
# 5    27  Female        Married   Employee  More than 50000
# 8    23  Female         Single    Student        No Income
# 11   23    Male         Single    Student   Below Rs.10000
# 16   28  Female         Single   Employee   25001 to 50000
# 34   22  Female         Single    Student        No Income
#
#    Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 5               Post Graduate            2   12.9299    77.6848    560103
# 8               Post Graduate            2   12.9766    77.5993    560001
# 11              Post Graduate            2   12.9770    77.5773    560009
# 16              Post Graduate            2   12.9783    77.6408    560038
# 34              Post Graduate            2   12.9119    77.6446    560102
#
#    Output   Feedback Unnamed: 12
# 5     Yes   Positive         Yes
# 8     Yes   Positive         Yes
# 11    Yes  Negative          Yes
# ...

# %%
[

# %%
onlinefood['Occupation'].value_counts()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %% [markdown]
# # Kako house wife obicno ne rade nista u klasicnom smislu, ocekujemo da nemaju visoka primanja.

# %% [markdown]
# ## Tabela korelacije

# %% [markdown]
# $[1, 2, 3, 4, 5]   [2, 4, 6, 8, 10]$
# $[1, 2,3,4,5] [0.2, 0.4,0.6,0.8, 1]$

# %%
onlinefood.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 onlinefood.corr()
#
# File ~\Desktop\UNZE\DataMiningVjezbe\DM\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\Desktop\UNZE\DataMiningVjezbe\DM\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# ...
