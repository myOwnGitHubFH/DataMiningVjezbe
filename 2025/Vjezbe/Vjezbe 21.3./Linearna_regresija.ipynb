# %%
import pandas as pd

# %%
df = pd.read_csv("life_expectancy_data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.tail()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
# 2934             26     4.06                     0.0          7.0       998
# 2935             25     4.43                     0.0         73.0       304
# 2936             25     1.72                     0.0         76.0       529
# 2937             24     1.68                     0.0         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df_sweden = df[df['Country'] == 'Sweden']
df_sweden.head()
# Out:
#      Country  Year     Status  Life expectancy   Adult Mortality  \
# 2505  Sweden  2015  Developed              82.4             53.0
# 2506  Sweden  2014  Developed              82.3             54.0
# 2507  Sweden  2013  Developed              81.9             57.0
# 2508  Sweden  2012  Developed              81.7             57.0
# 2509  Sweden  2011  Developed              81.7             58.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2505              0      NaN                0.000000         67.0        22
# 2506              0      7.3             1142.212403         67.0        26
# 2507              0      7.3             1212.666327         67.0        51
# 2508              0      7.4            10947.023270         53.0        30
# 2509              0      7.4            11477.667100         42.0        26
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# ...

# %%
df_italy = df[df['Country'] == 'Italy']
df_italy.head(20)
# Out:
#      Country  Year     Status  Life expectancy   Adult Mortality  \
# 1282   Italy  2015  Developed              82.7             56.0
# 1283   Italy  2014  Developed              82.5             57.0
# 1284   Italy  2013  Developed              82.3             58.0
# 1285   Italy  2012  Developed              82.0              6.0
# 1286   Italy  2011  Developed              82.0              6.0
# 1287   Italy  2010  Developed              81.8              6.0
# 1288   Italy  2009  Developed              81.6             61.0
# 1289   Italy  2008  Developed              81.5             61.0
# 1290   Italy  2007  Developed              81.3             63.0
# 1291   Italy  2006  Developed              81.2             65.0
# 1292   Italy  2005  Developed              88.0             66.0
# 1293   Italy  2004  Developed              89.0             66.0
# 1294   Italy  2003  Developed              79.9             72.0
# ...

# %%
df_japan = df[df['Country'] == 'Japan']
df_japan.head(20)
# Out:
#      Country  Year     Status  Life expectancy   Adult Mortality  \
# 1314   Japan  2015  Developed              83.7             55.0
# 1315   Japan  2014  Developed              83.5             57.0
# 1316   Japan  2013  Developed              83.5             56.0
# 1317   Japan  2012  Developed              83.3             58.0
# 1318   Japan  2011  Developed              82.5             64.0
# 1319   Japan  2010  Developed              83.0             62.0
# 1320   Japan  2009  Developed              83.0             64.0
# 1321   Japan  2008  Developed              82.7             66.0
# 1322   Japan  2007  Developed              82.6             67.0
# 1323   Japan  2006  Developed              82.4             68.0
# 1324   Japan  2005  Developed              82.0             69.0
# 1325   Japan  2004  Developed              82.1             68.0
# 1326   Japan  2003  Developed              81.9              7.0
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df['Status'].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2013    193
# 2015    183
# 2014    183
# 2012    183
# 2011    183
# 2010    183
# 2009    183
# 2008    183
# 2007    183
# 2006    183
# 2005    183
# 2004    183
# 2003    183
# 2002    183
# 2001    183
# 2000    183
# Name: count, dtype: int64

# %%
df_2013 = df[df['Year'] == 2013]
df_2014 = df[df['Year'] == 2014]

# %%
list_2013 = (df_2013['Country'].value_counts().index)
list_2014 = (df_2014['Country'].value_counts().index)

# %%
print(len(list_2013))
print(len(list_2014))
# Out:
# 193
# 183

# %%
set_2013 = set(list_2013)
set_2014 = set(list_2014)

diff_2013_14 = set_2013.difference(set_2014)

# %%
diff_2013_14
# Out:
# {'Cook Islands',
#  'Dominica',
#  'Marshall Islands',
#  'Monaco',
#  'Nauru',
#  'Niue',
#  'Palau',
#  'Saint Kitts and Nevis',
#  'San Marino',
#  'Tuvalu'}

# %%
df = df[~df['Country'].isin(diff_2013_14)]

# %%
df['Year'].value_counts()
# Out:
# Year
# 2015    183
# 2014    183
# 2013    183
# 2012    183
# 2011    183
# 2010    183
# 2009    183
# 2008    183
# 2007    183
# 2006    183
# 2005    183
# 2004    183
# 2003    183
# 2002    183
# 2001    183
# 2000    183
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
df_hepatitis_null = df[df['Hepatitis B'].isna()]

# %%
df_hepatitis_null['Country'].value_counts()
# Out:
# Country
# Denmark                                                 16
# United Kingdom of Great Britain and Northern Ireland    16
# Norway                                                  16
# Japan                                                   16
# Switzerland                                             16
#                                                         ..
# Grenada                                                  1
# Mozambique                                               1
# Antigua and Barbuda                                      1
# Russian Federation                                       1
# Panama                                                   1
# Name: count, Length: 98, dtype: int64
