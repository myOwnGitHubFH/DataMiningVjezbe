# %%
import pandas as pd
import matplotlib.pyplot as plt

# import express.plotly

# %% [markdown]
# # Pokusaji dokazivanja linearne separabilnost

# %%
df = pd.read_csv("../Vjezbe_April_2024/datasets/LogReg/weatherAUS.csv")

# %%
df.dropna(inplace=True)

# %%
df = df.sample(frac = 1)

# %%
df.head()
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 84566   2010-01-11       Brisbane     20.8     30.5       0.0          7.0
# 123096  2015-06-22          Perth     10.0     15.8      13.4          1.8
# 72165   2014-02-05        Mildura     16.7     38.1       0.0         11.6
# 71220   2011-05-08        Mildura      4.4     19.4       0.0          1.4
# 23172   2014-11-13  NorfolkIsland     15.4     20.6       0.8          7.1
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 84566       12.2         ENE           33.0         SE  ...        61.0
# 123096       7.2          SW           43.0          S  ...        82.0
# 72165       12.7          NE           33.0         SE  ...        46.0
# 71220        9.4         SSE           28.0          S  ...        72.0
# 23172        9.6         WSW           56.0        SSW  ...        66.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
X_svm = df[["MinTemp", "MaxTemp", "Pressure9am"]]

# %%
X_svm.head()
# Out:
#         MinTemp  MaxTemp  Pressure9am
# 84566      20.8     30.5       1016.7
# 123096     10.0     15.8       1021.7
# 72165      16.7     38.1       1014.8
# 71220       4.4     19.4       1018.0
# 23172      15.4     20.6       1014.4

# %%
y_svm = df['RainTomorrow']

# %%
y_svm.head()
# Out:
# 84566     No
# 123096    No
# 72165     No
# 71220     No
# 23172     No
# Name: RainTomorrow, dtype: object

# %%
y_svm.value_counts()
# Out:
# RainTomorrow
# No     43993
# Yes    12427
# Name: count, dtype: int64

# %%
# Map 'y' to colors
color_map = {'No': 'red', 'Yes': 'green'}  # Red for 'No', green for 'Yes'
colors = df['RainTomorrow'].map(color_map)

# %%
cols = X_svm.columns

# %%
cols = list(cols)

# %%
for i in range(len(cols)):
    for j in range(i+1, len(cols)):
        
        x_axis_name = cols[i]
        y_axis_name = cols[j]
        
        x_axis = X_svm[cols[i]]
        y_axis = X_svm[cols[j]]

        # Plotting
        plt.figure(figsize=(8, 6))
        plt.scatter(x_axis, y_axis, c=colors, label=f'{x_axis_name} vs {y_axis_name}')
        plt.xlabel(f'{x_axis_name}')
        plt.ylabel(f'{y_axis_name}')
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# # One vs one
# # One vs all
